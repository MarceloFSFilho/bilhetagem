# %%
def busca_linha(linha):
    dados_linhas = {
        1:'NÃO CADASTRADA',
        0:'NÃO CADASTRADA',
        679:'133028',
        206: '133002',
        208: '133004',
        210: '133006',
        211: '133007', 
        214: '133009', 
        216: '133010', 
        212: '133011', 
        213: '133012',
        215: '133013',
        619: '133014',
        620: '133015',
        218: '133016', 
        217: '133020',
        219: '133021',
        221: '133023',
        569: '133024',
        701: '128039',
        205: '133061',
        207: '133062',
        203: '133063',
        195: '007013',
        196: '007014',
        197: '007015', 
        198: '007016', 
        199: '007017',
        220: '133026', 
        163: '128011',
        156: '128004',
        175: '128025', 
        209: '133005',
        310: '171001', 
        300: '167001',
        303: '167002',
        307: '167003', 
        299: '167004', 
        305: '167005', 
        306: '167006', 
        308: '167007', 
        304: '167008', 
        302: '167009', 
        309: '171002', 
        512: '133027', 
        513: '133028', 
        153: '128001',
        154: '128002', 
        155: '128003',
        157: '128005', 
        158: '128006', 
        159: '128007',
        160: '128008', 
        161: '128009',
        162: '128010', 
        164: '128012', 
        243: '128013', 
        165: '128014', 
        166: '128015',
        167: '128016', 
        168: '128017', 
        169: '128018', 
        170: '128019', 
        171: '128020',
        172: '128021', 
        173: '128022',
        174: '128024',
        176: '128026', 
        177: '128027', 
        178: '128028', 
        179: '128029', 
        180: '128030', 
        181: '128031',
        182: '128032', 
        183: '128033', 
        184: '128034', 
        185: '128036', 
        186: '128037',
        187: '128038',
        684: '133038', 
        682: '133036', 
        683: '133037',
        685: '133039',
        686: '133040',
        716: '167014', 
        717: '167016', 
        713: '007018', 
        719: '007019',
        188: '007001', 
        189: '007002', 
        190: '007003', 
        191: '007004', 
        192: '007005', 
        193: '007007',
        194: '007011', 
        612: '007050', 
        204: '133001',
        202: '133003', 
        611: '133035', 
        668: '133029', 
        670: '133030', 
        618: '128040', 
        671: '133032', 
        669: '133031', 
        677: '167011',
        678: '167013',
        700: '128042', 
        715: '171003'}
    
    if not linha in dados_linhas:
        return 99999
    
    else:
        return dados_linhas[linha]
